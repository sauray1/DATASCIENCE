# %%
Print("HELLO WORLD")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 Print("HELLO WORLD")
#
# NameError: name 'Print' is not defined

# %%
print("hewllo world");
# Out:
# hewllo world
